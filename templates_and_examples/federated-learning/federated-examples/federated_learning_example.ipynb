# %%
# %load_ext autoreload
# %autoreload 2
from argparse import Namespace
from cryptography.fernet import Fernet
import requests
import time
import datetime as datetime
from datetime import timedelta
import numpy as np
import json
import os
import tarfile
import glob
from minio import Minio
from minio.error import (InvalidResponseError, S3Error)
import sys

sys.path.insert(0, '/appdata/dev')

from kaapana_federated.utils import get_auth_headers, get_minio_client, get_presigend_url, get_remote_header

# %%
def get_init_conf():
    return {
        "query": {
            "bool": {
                "must": [
                    {
                        "match_all": {}
                    },
                    {
                        "match_all": {}
                    },
                    {
                        "match_phrase": {
                            "00120020 ClinicalTrialProtocolID_keyword.keyword": {
                                "query": "satori-ana"
                            }
                        }
                    },
                    {
                        "match_phrase": {
                            "00080060 Modality_keyword.keyword": {
                                "query": "SEG"
                            }
                        }
                    }
                ],
                "filter": [],
                "should": [],
                "must_not": []
            }
        },
        "index": "meta-index",
        "dag": "dev-federated",
        "cohort_limit": 2,
        "form_data": {
            "task": "Task136_RACOON_260122-Federated",
            "model": "3d_lowres",
            "train_network_trainer": "nnUNetTrainerV2",
            "prep_modalities": "CT",
            "node_uid": "node_uid_125497293966312",
            "shuffle_seed": 0,
            "test_percentage": 0,
            "training_description": "nnUnet Segmentation",
            "body_part": "N/A",
            "train_max_epochs": 50,
            "input": "SEG"
        },
        "rest_call": {
        },
        "federated": {
            "node_id": 'dkfz',
            "federated_operators": ['unet-ct', 'local-dev'], 
            "skip_operators": ["workflow-cleaner"]
        }
    }

# %%
def get_init_conf():
    return {
        "query": {
            "bool": {
                "must": [
                    {
                        "match_all": {}
                    },
                    {
                        "match_all": {}
                    },
                    {
                        "match_phrase": {
                            "00120020 ClinicalTrialProtocolID_keyword.keyword": {
                                "query": "satori-ana"
                            }
                        }
                    },
                    {
                        "match_phrase": {
                            "00080060 Modality_keyword.keyword": {
                                "query": "SEG"
                            }
                        }
                    }
                ],
                "filter": [],
                "should": [],
                "must_not": []
            }
        },
        "index": "meta-index",
        "dag": "nnunet-training",
        "cohort_limit": 4,
        "form_data": {
            "task": "Task136_RACOON_310122-Federated",
            "model": "3d_lowres",
            "train_network_trainer": "nnUNetTrainerV2",
            "prep_modalities": "CT",
            "node_uid": "node_uid_125497293966312",
            "shuffle_seed": 0,
            "test_percentage": 0,
            "training_description": "nnUnet Segmentation",
            "body_part": "N/A",
            "train_max_epochs": 2,
            "input": "SEG"
        },
        "rest_call": {
        },
        "federated": {
            "node_id": 'dkfz',
            "federated_operators": ['nnunet-training'], 
            "skip_operators": ["model2dicom", "dcmsend", "dcmsend-pdf", "zip-unzip-training", "workflow-cleaner"]
        }
    }

# %%
sites = [
    {
        'node_id': 'dkfz',
    }
]
r = requests.get('http://federated-backend-service.base.svc:5000/client/client-kaapana-instance')
client_network = r.json()
client_network
for site in sites:
    client_network['node_id'] = site['node_id']
    r = requests.post('http://federated-backend-service.base.svc:5000/client/remote-kaapana-instance', json=client_network)
    print(r)
    print(r.json())

# %%
def fernet_encryptfile(filepath, key):
    if key == 'deactivated':
        return
    fernet = Fernet(key.encode())
    with open(filepath, 'rb') as file:
        original = file.read()
    encrypted = fernet.encrypt(original)
    with open(filepath, 'wb') as encrypted_file:
        encrypted_file.write(encrypted)
        
def fernet_decryptfile(filepath, key):
    if key == 'deactivated':
        return
    fernet = Fernet(key.encode())
    with open(filepath, 'rb') as enc_file:
        encrypted = enc_file.read()
    decrypted = fernet.decrypt(encrypted)
    with open(filepath, 'wb') as dec_file:
        dec_file.write(decrypted)

def apply_tar_action(dst_filename, src_dir):
    print(f'Tar {src_dir} to {dst_filename}')
    with tarfile.open(dst_filename, "w:gz") as tar:
        tar.add(src_dir, arcname=os.path.basename(src_dir))

def apply_untar_action(src_filename, dst_dir):
    print(f'Untar {src_filename} to {dst_dir}')
    with tarfile.open(src_filename, "r:gz")as tar:
        tar.extractall(dst_dir)

def raise_kaapana_connection_error(r):
    if r.history:
        raise ConnectionError('You were redirect to the auth page. Your token is not valid!')
    try:
        r.raise_for_status()
    except:
        raise ValueError(f'Something was not okay with your request code {r}: {r.text}!')
    print('Response', r)

def update_conf(data, site, fl_run_id, minioClient, federated_bucket):
    data['conf']['federated']['site'] = site
    minio_urls = {}
    minio_urls['conf'] = {
        'get': get_presigend_url(minioClient, 'GET', federated_bucket, os.path.join(fl_run_id, site, 'conf.tar.gz')),
        'put': get_presigend_url(minioClient, 'PUT', federated_bucket,  os.path.join(fl_run_id, site,'conf.tar.gz'))
    }
    for federated_operator in data['conf']['federated']['federated_operators']:
        minio_urls[federated_operator] = {  
            'get': get_presigend_url(minioClient, 'GET', federated_bucket, os.path.join(fl_run_id, site, f'{federated_operator}.tar.gz')),
            'put': get_presigend_url(minioClient, 'PUT', federated_bucket,  os.path.join(fl_run_id, site, f'{federated_operator}.tar.gz'))
        }
    data['conf']['federated']['minio_urls'] = minio_urls
        
minioClient = get_minio_client('kaapanaminio', 'Kaapana2020')

fl_working_dir = '/appdata/dev/federated-local-workspace'
FEDERATED_BUCKET = 'january'
fl_run_id = '123'
dry_run = False


# r = requests.get('http://federated-backend-service.base.svc:5000/client/client-network')
# raise_kaapana_connection_error(r)
# client_network = r.json()
    
if not minioClient.bucket_exists(FEDERATED_BUCKET):
    minioClient.make_bucket(FEDERATED_BUCKET)

client_url = 'http://federated-backend-service.base.svc:5000/client'
r = requests.get(f'{client_url}/remote-kaapana-instances')
remote_sites = r.json()

for rn in range(0, 3):
    updated = {site['node_id']: False for site in remote_sites}
    fl_working_dir_round = os.path.join(fl_working_dir, str(rn))
    # Starting round!
    now = datetime.datetime.now(tz=datetime.timezone.utc)
    for site_info in remote_sites:
        if rn == 0:
            conf = get_init_conf()
            conf['federated']['from_previous_dag_run'] =  None
            conf['federated']['rounds'] = [0] 
        else:
            with open(os.path.join(os.path.join(fl_working_dir, str(rn-1)), fl_run_id, site_info['node_id'], 'conf', 'conf.json'), "r", encoding='utf-8') as jsonData:
                conf = json.load(jsonData)
        meta_data = {
            'conf': conf
        }
        update_conf(meta_data, site_info['node_id'], fl_run_id, minioClient, FEDERATED_BUCKET)
        remote_backend_url = f'{site_info["protocol"]}://{site_info["host"]}:{site_info["port"]}/federated-backend/remote'
#         print(f'Sending data to {remote_backend_url}')
#         r = requests.get(f'{remote_backend_url}/health-check', verify=False, headers=get_remote_header(site_info["token"]))
        raise_kaapana_connection_error(r)
        r = requests.post(f'{client_url}/job', json={
            "dry_run": dry_run,
            "conf_data": meta_data,
            "status": "queued",
            "kaapana_instance_id": site_info['id']
        },  verify=False,  headers=get_remote_header(site_info["token"]))
        job = r.json()
        print('Created Job')
        print(job)
#         r = requests.post(f'{remote_backend_url}/trigger-workflow', params={'dry_run': dry_run}, json=meta_data,  verify=False,  headers=get_remote_header(site["token"]))
        raise_kaapana_connection_error(r)
        site_info['remote_job_id'] = job['id']
    if dry_run is True:
        print(r.text)
        break
        
    # Waiting for updated files
    print('Waiting for updates')
    for idx in range(10000):
        if idx%60 == 0:
            print(f'{60*(idx+1)} seconds')
            
        time.sleep(2) 
        for site_info in remote_sites:
            remote_backend_url = f'{site_info["protocol"]}://{site_info["host"]}:{site_info["port"]}/federated-backend/remote'
            r = requests.get(f'{remote_backend_url}/job', params={
                "job_id": site_info["remote_job_id"]
            },  verify=site_info['ssl_check'],  headers={'FederatedAuthorization': f'{site_info["token"]}'})
            job = r.json()
            print(job['status'])
            if job['status'] == 'finished':
                updated[site_info['node_id']] = True
#         for site_info in remote_sites:
#             for obj in minioClient.list_objects(FEDERATED_BUCKET, os.path.join(fl_run_id, site_info['node_id'], 'conf')):
#                 if now < obj.last_modified:
#                     updated[site_info['node_id']] = True
        if np.sum(list(updated.values())) == len(remote_sites):
            break
            
    if bool(np.sum(list(updated.values())) == len(remote_sites)) is False:
        print('Update list')
        for k, v in updated.items():
            print(k, v)
        raise ValueError('There are lacking updates, please check what is going on!')

    # Downloading all objects
    for site_info in remote_sites:
        objects = minioClient.list_objects(FEDERATED_BUCKET, os.path.join(fl_run_id, site_info['node_id']), recursive=True)
        # assert len(list(objects)) != 0, 'There seems to be an error somewhere, we can not find the files on minio!' # Seems to destroy the objects object!
        for obj in objects:
            # https://github.com/minio/minio-py/blob/master/minio/datatypes.py#L103
            if obj.is_dir:
                pass
            else:
#                 file_dir = os.path.join(fl_working_dir_round, os.path.dirname(obj.object_name))
                file_path = os.path.join(fl_working_dir_round, obj.object_name)
                file_dir = os.path.dirname(file_path)
                os.makedirs(file_dir, exist_ok=True)
                minioClient.fget_object(FEDERATED_BUCKET,  obj.object_name, file_path)
#                 dst_dir = os.path.join(file_dir, os.path.basename(obj.object_name).replace('.tar.gz', ''))
                fernet_decryptfile(file_path, site_info['fernet_key'])
                apply_untar_action(file_path, file_dir)
     # Working with downloaded objects

    print('Finished round', rn)

# %%
site_info = remote_sites[0]
remote_backend_url = f'{site_info["protocol"]}://{site_info["host"]}:{site_info["port"]}/federated-backend/remote'
r = requests.get(f'{remote_backend_url}/job', params={
    "job_id": site_info["remote_job_id"]
},  verify=site_info['ssl_check'],  headers={'FederatedAuthorization': f'{site_info["token"]}'})
job = r.json()

# %%
conf

# %%
remote_token = 'e15909a1-6d3e-4826-aa3d-152dce320ff9'
remote_backend_url = 'http://federated-backend-service.base.svc:5000/remote'
r = requests.get(f'{remote_backend_url}/health-check',  headers=get_remote_header(remote_token))
raise_kaapana_connection_error(r)
print(r.json())

# %%
r = requests.post(f'{remote_backend_url}/trigger-workflow', params={'dry_run': dry_run}, json=meta_data,  verify=False,  headers=get_remote_header(site_info["token"]))
raise_kaapana_connection_error(r)
print(r.json())

# %%
put_data = get_presigend_url(minioClient, 'PUT', 'january', 'aaa.txt')
get_data = get_presigend_url(minioClient, 'GET', 'january', 'aaa.txt')

# %%
minio_presigned_url = f'{remote_backend_url}/minio-presigned-url'
data = get_data.copy()
filename = 'test.txt'
with requests.get(minio_presigned_url, verify=False, stream=True, headers={**get_remote_header(site_info["token"]), 'presigned-url': data['path']}) as r:
    raise_kaapana_connection_error(r)
    print(r.text)
    with open(filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192): 
            # If you have chunk encoded response uncomment if
            # and set chunk_size parameter to None.
            #if chunk: 
            f.write(chunk)

# %%
remote_backend_url = 'https://10.133.28.53:443/federated-backend/remote/minio-presigned-url'
'https://10.133.28.53/federated-backend/remote/minio-presigned-url'
minio_presigned_url = f'{remote_backend_url}'
data = put_data.copy()
r = requests.post(minio_presigned_url, verify=False, files={'file': open('../../january/123/essen/local-dev.tar.gz', "rb")}, headers={**get_remote_header(site_info["token"]), 'presigned-url': data['path']})
r.text

# %%
{
            'conf': get_init_conf()
        }

# %%
for li in range(0, idx_1):
    print(li)
